# %%
pip install gTTS
# Out:
# ...
#   Created wheel for gtts-token: filename=gTTS_token-1.1.3-cp36-none-any.whl size=4096 sha256=8754ddd0aba382ee0808b775bb8fe9cf3f3a36d9a1139c82a6b79f2b8e4a5c74
#   Stored in directory: /root/.cache/pip/wheels/dd/11/61/33f7e51bf545e910552b2255eead2a7cd8ef54064b46dceb34
# Successfully built gtts-token
# ...

# %%
# Import the required module for text  
# to speech conversion 
from gtts import gTTS 
  
# This module is imported so that we can  
# play the converted audio 
import os

# %%
# Language in which you want to convert 
language = 'en'

# %%
file = open("drive/My Drive/studies/python/projects/text to speech project/textfile3.txt", "r").read().replace("\n", " ")

# %%
# Passing the text and language to the engine,  
# here we have marked slow=False. Which tells  
# the module that the converted audio should  
# have a high speed 
speech = gTTS(text = str('textfile3.txt'), lang = language, slow = False)
#myobj = gTTS(text='Global warming is the long-term rise in the average temperature of the Earth’s climate system', lang=language, slow=False)

# %%
# Saving the converted audio in a mp3 file named 
# welcome  

speech.save("drive/My Drive/studies/python/projects/text to speech project/textfile3.mp3")

#myobj.save("test2.mp3")

# %%
pip install playsound

# %%
from playsound import playsound

# %%
# Playing the converted file 

# import playsound

# playsound.playsound("drive/My Drive/studies/python/projects/text to speech project/test.mp3", True)

# #os.system("drive/My Drive/studies/python/projects/text to speech project/test.mp3")

# os.system("afplay test.mp3")


playsound("drive/My Drive/studies/python/projects/text to speech project/textfile3.mp3")


# import IPython.display as ipd

# ipd.Audio(filename='textfile3.mp3', autoplay=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-989a12416c63> in <module>()
#      10
#      11
# ---> 12 playsound("drive/My Drive/studies/python/projects/text to speech project/textfile3.mp3")
#      13
#      14
#
# /usr/local/lib/python3.6/dist-packages/playsound.py in _playsoundNix(sound, block)
#      90
#      91     import gi
# ---> 92     gi.require_version('Gst', '1.0')
#      93     from gi.repository import Gst
#      94
#
# /usr/lib/python3/dist-packages/gi/__init__.py in require_version(namespace, version)
#     128     available_versions = repository.enumerate_versions(namespace)
#     129     if not available_versions:
# --> 130         raise ValueError('Namespace %s not available' % namespace)
#     131
#     132     if version not in available_versions:
#
# ValueError: Namespace Gst not available
